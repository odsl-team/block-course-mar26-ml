# %% [markdown]
# # Convolutional Neural Networks
#
# **Lecturer:** Nicole Hartman
# **Date:** 24th Mar 2026
#
# Also gratefully borrowing from Baran's [notebook](https://github.com/odsl-team/block-course-apr24-ML/blob/main/Exercises/w2_cnn.ipynb) teaching the course last year.
#
# **Goal:** We're going to walk through a CNN step-by step to support our understanding in the lecture
#
# We'll be looking at the MNIST dataset

# %%
pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 3.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml("mnist_784", version=1, as_frame=False)
X, y = mnist.data, mnist.target.astype(int)

x_train, x_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]

# %%
import mnist
mnist.datasets_url = "https://ossci-datasets.s3.amazonaws.com/mnist"

# Load the labels for the training and test datasets.
train_labels = mnist.train_labels()
test_labels = mnist.test_labels()

# Calculate the mean and standard deviation of the training images.
scale_mean, scale_std = mnist.train_images().mean(), mnist.train_images().std()

# Standardize the training and test images by subtracting the mean and dividing by the standard deviation.
train_images = (mnist.train_images() - scale_mean) / scale_std
test_images = (mnist.test_images() - scale_mean) / scale_std
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 mnist.datasets_url = "https://ossci-datasets.s3.amazonaws.com/mnist"
#       4 # Load the labels for the training and test datasets.
# ----> 5 train_labels = mnist.train_labels()
#       6 test_labels = mnist.test_labels()
#       8 # Calculate the mean and standard deviation of the training images.
#
# File ~/miniforge3/envs/environment_nnpdf/lib/python3.12/site-packages/mnist/__init__.py:189, in train_labels()
#     179 def train_labels():
#     180     """Return train labels from Yann LeCun MNIST database as a numpy array.
#     181     Download the file, if not already found in the temporary directory of
#     182     the system.
#    (...)    187         Numpy array with the labels 0 to 9 in the train MNIST database.
#     188     """
# ...

# %%
**Gotchas intentionally in the notebook:**
- Normalize the inputs?
-
